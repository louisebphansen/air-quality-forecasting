# %%
import matplotlib.pyplot as plt 
import pandas as pd 
import os

# %%
NO2_nhits = os.path.join('out', 'forecasts', 'NHITS', 'NO2_temp_wind-speed_forecast.csv')
no2_forecast = pd.read_csv(NO2_nhits)

# %%
os.listdir(os.path.join('out', 'forecasts'))
# Out:
# ['NHITS']

# %%
for dir in 
for particle in ['NO2', 'O3', 'PM2.5', 'PM10']:
    forecast_path

# %%
no2_forecast
# Out:
#     Unnamed: 0 unique_id                   ds      NHITS   NO2
# 0            0       NO2  2026-04-15 00:00:00  10.881932   9.8
# 1            1       NO2  2026-04-15 01:00:00  11.025374   7.8
# 2            2       NO2  2026-04-15 02:00:00  11.132595   4.0
# 3            3       NO2  2026-04-15 03:00:00  11.053903   4.4
# 4            4       NO2  2026-04-15 04:00:00  10.927878   3.7
# ..         ...       ...                  ...        ...   ...
# 91          91       NO2  2026-04-18 19:00:00   8.618606   9.9
# 92          92       NO2  2026-04-18 20:00:00   9.181888  10.7
# 93          93       NO2  2026-04-18 21:00:00   9.742796  11.6
# 94          94       NO2  2026-04-18 22:00:00  10.184305  10.7
# 95          95       NO2  2026-04-18 23:00:00  10.378268  10.2
#
# [96 rows x 5 columns]

# %%
df = pd.read_csv(os.path.join('aarhus_air_quality.csv'))
df['Recorded'] = pd.to_datetime(df['Recorded'])

test_size = 96
train_df = df.iloc[:-test_size]
test_df  = df.iloc[-test_size:]

# %%
test_df['NO2']
# Out:
# 8688     9.8
# 8689     7.8
# 8690     4.0
# 8691     4.4
# 8692     3.7
#         ...
# 8779     9.9
# 8780    10.7
# 8781    11.6
# 8782    10.7
# 8783    10.2
# Name: NO2, Length: 96, dtype: float64

# %%
no2_forecast['NO2'] = test_df['NO2'].values

# %%
no2_forecast['NO2']
# Out:
# 0      9.8
# 1      7.8
# 2      4.0
# 3      4.4
# 4      3.7
#       ...
# 91     9.9
# 92    10.7
# 93    11.6
# 94    10.7
# 95    10.2
# Name: NO2, Length: 96, dtype: float64
